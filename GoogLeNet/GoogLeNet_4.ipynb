# %%
# !pip install torch_optimizer

import numpy as np
import random
import math
import time
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

from torch.optim import Optimizer
import torch_optimizer as optim

from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler

from torchvision import datasets
from torchvision.transforms import transforms

import torch.nn.functional as F


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
name = torch.cuda.get_device_name(0)
print("GPU: " + name)

random_seed = 0

torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

np.random.seed(random_seed)
random.seed(random_seed)


class EarlyStopping:
    def __init__(self, patience=10, path='checkpoint.pt'):
        
        self.patience = patience
        self.counter = 0
        self.best_score = None
        self.val_loss_min = np.Inf
        self.early_stop = False

        self.path = path



    def __call__(self, val_loss, model):

        score = val_loss

        if self.best_score is None:
            self.best_score = score
            
            print('Validation loss decreased ({:.4f} --> {:.4f}).  Saving model ...'.format(self.val_loss_min, val_loss))
            torch.save(model.state_dict(), self.path)
            self.val_loss_min = val_loss

        elif score > self.best_score:
            self.counter += 1
            print("EarlyStopping counter: {} out of {}".format(self.counter, self.patience))

            if self.counter >= self.patience:
                self.early_stop = True

        else:
            self.best_score = score
            self.counter = 0

            print('Validation loss decreased --- Saving model ...')
            torch.save(model.state_dict(), self.path)
            self.val_loss_min = val_loss



def get_data_len_index(pad=4, randomcrop=32):
    data_shuffle = []

    transform = transforms.Compose([
                                    transforms.Pad(pad),
                                    transforms.RandomHorizontalFlip(),
                                    transforms.RandomCrop(randomcrop),
                                    transforms.ToTensor()
    ])

    train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                     train=True,
                                     transform=transform,
                                     download=True) 
    
    len_train = len(train_dataset)
    index_train = list(range(len_train))
    

    data_shuffle.append(len_train)
    data_shuffle.append(index_train)
    data_shuffle.append(train_dataset)

    return data_shuffle



def test_model(model, batch_size=128):
    model.eval()
    test_loss, correct, total = 0, 0, 0

    with torch.no_grad():
        for images, labels in test_loader :
            images, labels = images.to(device), labels.to(device)

            output = model(images)
            test_loss += loss_function(output, labels).item()

            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(labels.view_as(pred)).sum().item()

            total += labels.size(0)

    print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
            test_loss /total, correct, total,
            100. * correct / total))
    

def train_model(model, batch_size, n_epochs, patience, loader):
    train_loader = loader[0]
    valid_loader = loader[1]
    
    train_losses = []
    valid_losses = []

    avg_train_losses = []
    avg_valid_losses = []

    early_stopping = EarlyStopping(patience=patience)

    model.train()

    start = time.time()

    for epoch in range(1,n_epochs+1):
        print("{}th Epoch starting.".format(epoch))

        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()

            output = model(images)

            train_loss = loss_function(output, labels)

            train_loss.backward()

            optimizer.step()

            loss = train_loss.item()


            train_losses.append(loss)


        model.eval()

        with torch.no_grad():
            for images, labels in valid_loader:
                images , labels = images.to(device), labels.to(device)

                output = model(images)

                valid_loss = loss_function(output, labels)

                loss = valid_loss.item()

                valid_losses.append(loss)
        
        loss_train = np.average(train_losses)
        loss_valid = np.average(valid_losses)

        avg_train_losses.append(loss_train)
        avg_valid_losses.append(loss_valid)

        print("Epoch [{}] Train Loss: {:.4f} & Validation Loss: {:.4f}".format(epoch, loss_train, loss_valid))

        train_losses = []
        valid_losses = []

        early_stopping(loss_valid, model)

        if early_stopping.early_stop:
            print("Early Stopping!!")
            end = time.time()
            #print(end-start)
            break

    model.load_state_dict(torch.load('checkpoint.pt'))

    return model, avg_train_losses, avg_valid_losses



def train_KFold(model, batch_size, n_epochs, patience, data_info, fold):
        
    train_losses = []
    valid_losses = []

    loader = []

    path='checkpoint.pt'

    len_train = data_info[0]
    index_train = data_info[1]
    train_dataset = data_info[2]

    np.random.shuffle(index_train)

    split_size = len_train // fold

    start = time.time()
    for i in range(fold):

        valid_ind = index_train[split_size * i: split_size * (i+1)]
                
        if i == 0:
            train_ind = index_train[split_size * (i+1):]
                    
        elif i == 4:
            train_ind = index_train[:split_size*i]

        else:
            train_ind = index_train[:split_size * i] + index_train[split_size * (i+1):]

        train_sampler = SubsetRandomSampler(train_ind)
        valid_sampler = SubsetRandomSampler(valid_ind)    

        train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                                        batch_size=batch_size,
                                                        sampler = train_sampler,
                                                        num_workers=0)
                
        valid_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                                        batch_size=batch_size,
                                                        sampler = valid_sampler,
                                                        num_workers=0)
        
        loader.append(train_loader)
        loader.append(valid_loader)
                

        print("{} Fold is Training".format(i+1))

        model, avg_train_losses, avg_valid_losses = train_model(model, batch_size, n_epochs, patience, loader)
        
        train_losses.append(avg_train_losses)
        valid_losses.append(avg_valid_losses)
        
    end = time.time()

    print(end-start)

    return model, train_losses, valid_losses
# Out:
# Collecting torch_optimizer
#   Downloading https://files.pythonhosted.org/packages/ce/70/ca0cd259662eef5c9448d3ecf14af880bbfe76331e4eeab7b19827d6dbe6/torch_optimizer-0.0.1a17-py3-none-any.whl (69kB)
#      |████████████████████████████████| 71kB 6.0MB/s
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from torch_optimizer) (1.7.0+cu101)
# Collecting pytorch-ranger>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/0d/70/12256257d861bbc3e176130d25be1de085ce7a9e60594064888a950f2154/pytorch_ranger-0.1.1-py3-none-any.whl
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->torch_optimizer) (0.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->torch_optimizer) (0.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->torch_optimizer) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->torch_optimizer) (1.19.4)
# Installing collected packages: pytorch-ranger, torch-optimizer
# Successfully installed pytorch-ranger-0.1.1 torch-optimizer-0.0.1a17
# cuda:0
# GPU: Tesla P100-PCIE-16GB

# %%
class GoogLeNet(nn.Module):

    def __init__(self):
        super(GoogLeNet, self).__init__()        

        self.conv1 = BasicConv2d(3, 64, kernel_size=7, padding=3)
        self.conv2 = BasicConv2d(64, 64, kernel_size=1)
        self.conv3 = BasicConv2d(64, 192, kernel_size=5)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)  # 64 + 128 + 32 + 32 = 256
        self.inception3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception4a = Inception(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = Inception(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = Inception(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool2d(2, stride=2, ceil_mode=True)

        self.inception5a = Inception(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception(832, 384, 192, 384, 48, 128, 128)


        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.Linear(1024, 10)
        
        
    def forward(self, x):
        # N x 3 x 32 x 32
        x = self.conv1(x)
        # N x 64 x 32 x 32
        x = self.conv2(x)
        # N x 64 x 32 x 32
        x = self.conv3(x)
        # N x 192 x 28 x 28

        # N x 192 x 28 x 28
        x = self.inception3a(x)
        # N x 256 x 28 x 28
        x = self.inception3b(x)
        # N x 480 x 28 x 28
        x = self.maxpool3(x)
        # N x 480 x 14 x 14
        x = self.inception4a(x)
        # N x 512 x 14 x 14
        x = self.inception4b(x)
        # N x 512 x 14 x 14
        x = self.inception4c(x)
        # N x 512 x 14 x 14
        x = self.inception4d(x)
        # N x 528 x 14 x 14
        x = self.inception4e(x)
        # N x 832 x 14 x 14
        x = self.maxpool4(x)
        # N x 832 x 7 x 7
        x = self.inception5a(x)
        # N x 832 x 7 x 7
        x = self.inception5b(x)
        # N x 1024 x 7 x 7
        x = self.avgpool(x)
        # N x 1024 x 1 x 1
        x = torch.flatten(x, 1)
        # N x 1024
        x = self.dropout(x)
        x = self.fc(x)
        # N x 10 (num_classes)
        return x

# %%
class Inception(nn.Module):

    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()
        
        self.branch1 = BasicConv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv2d(in_channels, ch3x3red, kernel_size=1),
            BasicConv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(in_channels, ch5x5red, kernel_size=1),
            BasicConv2d(ch5x5red, ch5x5, kernel_size=5, padding=2)
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            BasicConv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        return torch.cat([branch1, branch2, branch3, branch4], 1)


class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Sequential(
                            nn.Conv2d(in_channels, out_channels, **kwargs),
                            nn.BatchNorm2d(out_channels),   #Batch norm here
                            nn.ReLU()
                            )
    def forward(self, x):
        return self.conv(x)

# %%
import torch.nn.init as init

def weight_init(m):
  if isinstance(m, nn.Conv2d):
    init.kaiming_uniform_(m.weight.data)

# %% [markdown]
# ### He Uniform Initialization
#
# ### Batch_size 63 --> 256
# ### Weight_decay 5e-4 --> 5e-5

# %%
data_info = get_data_len_index()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar_10data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Failed download. Trying https -> http instead. Downloading http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar_10data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./cifar_10data/cifar-10-python.tar.gz to ./cifar_10data/

# %%
model = GoogLeNet().to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = optim.RAdam(model.parameters(), weight_decay=5e-5)
batch_size = 256

# %%
model, train_losses, valid_losses = train_KFold(model, batch_size=batch_size, n_epochs=250, patience=20, data_info=data_info, fold=5)
# Out:
# 1 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 1.7708 & Validation Loss: 1.5543
# Validation loss decreased (inf --> 1.5543).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 2.1530 & Validation Loss: 1.7881
# EarlyStopping counter: 1 out of 20
# 3th Epoch starting.
# Epoch [3] Train Loss: 1.6895 & Validation Loss: 1.5912
# EarlyStopping counter: 2 out of 20
# 4th Epoch starting.
# Epoch [4] Train Loss: 1.5343 & Validation Loss: 1.5706
# EarlyStopping counter: 3 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 1.4095 & Validation Loss: 1.4158
# Validation loss decreased --- Saving model ...
# 6th Epoch starting.
# Epoch [6] Train Loss: 1.2918 & Validation Loss: 1.2647
# Validation loss decreased --- Saving model ...
# 7th Epoch starting.
# Epoch [7] Train Loss: 1.1824 & Validation Loss: 1.1501
# Validation loss decreased --- Saving model ...
# 8th Epoch starting.
# Epoch [8] Train Loss: 1.0896 & Validation Loss: 1.0440
# Validation loss decreased --- Saving model ...
# 9th Epoch starting.
# Epoch [9] Train Loss: 0.9686 & Validation Loss: 1.0967
# EarlyStopping counter: 1 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 0.8979 & Validation Loss: 0.9373
# Validation loss decreased --- Saving model ...
# 11th Epoch starting.
# Epoch [11] Train Loss: 0.8326 & Validation Loss: 0.8312
# Validation loss decreased --- Saving model ...
# 12th Epoch starting.
# Epoch [12] Train Loss: 0.7502 & Validation Loss: 0.7673
# Validation loss decreased --- Saving model ...
# 13th Epoch starting.
# Epoch [13] Train Loss: 0.7127 & Validation Loss: 0.7514
# Validation loss decreased --- Saving model ...
# 14th Epoch starting.
# Epoch [14] Train Loss: 0.6584 & Validation Loss: 0.7485
# Validation loss decreased --- Saving model ...
# 15th Epoch starting.
# Epoch [15] Train Loss: 0.6058 & Validation Loss: 0.7492
# EarlyStopping counter: 1 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 0.5948 & Validation Loss: 0.8106
# EarlyStopping counter: 2 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 0.5456 & Validation Loss: 0.6646
# Validation loss decreased --- Saving model ...
# 18th Epoch starting.
# Epoch [18] Train Loss: 0.5166 & Validation Loss: 0.5928
# Validation loss decreased --- Saving model ...
# 19th Epoch starting.
# Epoch [19] Train Loss: 0.4818 & Validation Loss: 0.5396
# Validation loss decreased --- Saving model ...
# 20th Epoch starting.
# Epoch [20] Train Loss: 0.4647 & Validation Loss: 0.6356
# EarlyStopping counter: 1 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 0.4445 & Validation Loss: 0.5387
# Validation loss decreased --- Saving model ...
# 22th Epoch starting.
# Epoch [22] Train Loss: 0.4272 & Validation Loss: 0.5774
# EarlyStopping counter: 1 out of 20
# 23th Epoch starting.
# Epoch [23] Train Loss: 0.4003 & Validation Loss: 0.5233
# Validation loss decreased --- Saving model ...
# 24th Epoch starting.
# Epoch [24] Train Loss: 0.3824 & Validation Loss: 0.5023
# Validation loss decreased --- Saving model ...
# 25th Epoch starting.
# Epoch [25] Train Loss: 0.3729 & Validation Loss: 0.4928
# Validation loss decreased --- Saving model ...
# 26th Epoch starting.
# Epoch [26] Train Loss: 0.3607 & Validation Loss: 0.5122
# EarlyStopping counter: 1 out of 20
# 27th Epoch starting.
# Epoch [27] Train Loss: 0.3378 & Validation Loss: 0.5012
# EarlyStopping counter: 2 out of 20
# 28th Epoch starting.
# Epoch [28] Train Loss: 0.3275 & Validation Loss: 0.5815
# EarlyStopping counter: 3 out of 20
# 29th Epoch starting.
# Epoch [29] Train Loss: 0.3132 & Validation Loss: 0.5234
# EarlyStopping counter: 4 out of 20
# 30th Epoch starting.
# Epoch [30] Train Loss: 0.3078 & Validation Loss: 0.5166
# EarlyStopping counter: 5 out of 20
# 31th Epoch starting.
# Epoch [31] Train Loss: 0.3031 & Validation Loss: 0.5271
# EarlyStopping counter: 6 out of 20
# 32th Epoch starting.
# Epoch [32] Train Loss: 0.2844 & Validation Loss: 0.4983
# EarlyStopping counter: 7 out of 20
# 33th Epoch starting.
# Epoch [33] Train Loss: 0.2787 & Validation Loss: 0.5328
# EarlyStopping counter: 8 out of 20
# 34th Epoch starting.
# Epoch [34] Train Loss: 0.2584 & Validation Loss: 0.4659
# Validation loss decreased --- Saving model ...
# 35th Epoch starting.
# Epoch [35] Train Loss: 0.2685 & Validation Loss: 0.5012
# EarlyStopping counter: 1 out of 20
# 36th Epoch starting.
# Epoch [36] Train Loss: 0.2496 & Validation Loss: 0.5597
# EarlyStopping counter: 2 out of 20
# 37th Epoch starting.
# Epoch [37] Train Loss: 0.2536 & Validation Loss: 0.4600
# Validation loss decreased --- Saving model ...
# 38th Epoch starting.
# Epoch [38] Train Loss: 0.2264 & Validation Loss: 0.5257
# EarlyStopping counter: 1 out of 20
# 39th Epoch starting.
# Epoch [39] Train Loss: 0.2322 & Validation Loss: 0.5189
# EarlyStopping counter: 2 out of 20
# 40th Epoch starting.
# Epoch [40] Train Loss: 0.2115 & Validation Loss: 0.5299
# EarlyStopping counter: 3 out of 20
# 41th Epoch starting.
# Epoch [41] Train Loss: 0.2224 & Validation Loss: 0.5168
# EarlyStopping counter: 4 out of 20
# 42th Epoch starting.
# Epoch [42] Train Loss: 0.2112 & Validation Loss: 0.5234
# EarlyStopping counter: 5 out of 20
# 43th Epoch starting.
# Epoch [43] Train Loss: 0.2062 & Validation Loss: 0.4985
# EarlyStopping counter: 6 out of 20
# 44th Epoch starting.
# Epoch [44] Train Loss: 0.2010 & Validation Loss: 0.5205
# EarlyStopping counter: 7 out of 20
# 45th Epoch starting.
# Epoch [45] Train Loss: 0.1952 & Validation Loss: 0.5265
# EarlyStopping counter: 8 out of 20
# 46th Epoch starting.
# Epoch [46] Train Loss: 0.1930 & Validation Loss: 0.5143
# EarlyStopping counter: 9 out of 20
# 47th Epoch starting.
# Epoch [47] Train Loss: 0.1843 & Validation Loss: 0.4963
# EarlyStopping counter: 10 out of 20
# 48th Epoch starting.
# Epoch [48] Train Loss: 0.1823 & Validation Loss: 0.4820
# EarlyStopping counter: 11 out of 20
# 49th Epoch starting.
# Epoch [49] Train Loss: 0.1808 & Validation Loss: 0.4655
# EarlyStopping counter: 12 out of 20
# 50th Epoch starting.
# Epoch [50] Train Loss: 0.1752 & Validation Loss: 0.4578
# Validation loss decreased --- Saving model ...
# 51th Epoch starting.
# Epoch [51] Train Loss: 0.1699 & Validation Loss: 0.5376
# EarlyStopping counter: 1 out of 20
# 52th Epoch starting.
# Epoch [52] Train Loss: 0.1719 & Validation Loss: 0.5297
# EarlyStopping counter: 2 out of 20
# 53th Epoch starting.
# Epoch [53] Train Loss: 0.1589 & Validation Loss: 0.5781
# EarlyStopping counter: 3 out of 20
# 54th Epoch starting.
# Epoch [54] Train Loss: 0.1647 & Validation Loss: 0.4940
# EarlyStopping counter: 4 out of 20
# 55th Epoch starting.
# Epoch [55] Train Loss: 0.1510 & Validation Loss: 0.5257
# EarlyStopping counter: 5 out of 20
# 56th Epoch starting.
# Epoch [56] Train Loss: 0.1637 & Validation Loss: 0.5533
# EarlyStopping counter: 6 out of 20
# 57th Epoch starting.
# Epoch [57] Train Loss: 0.1448 & Validation Loss: 0.5259
# EarlyStopping counter: 7 out of 20
# 58th Epoch starting.
# Epoch [58] Train Loss: 0.1523 & Validation Loss: 0.5224
# EarlyStopping counter: 8 out of 20
# 59th Epoch starting.
# Epoch [59] Train Loss: 0.1450 & Validation Loss: 0.4840
# EarlyStopping counter: 9 out of 20
# 60th Epoch starting.
# Epoch [60] Train Loss: 0.1553 & Validation Loss: 0.5444
# EarlyStopping counter: 10 out of 20
# 61th Epoch starting.
# Epoch [61] Train Loss: 0.1430 & Validation Loss: 0.5294
# EarlyStopping counter: 11 out of 20
# 62th Epoch starting.
# Epoch [62] Train Loss: 0.1310 & Validation Loss: 0.6498
# EarlyStopping counter: 12 out of 20
# 63th Epoch starting.
# Epoch [63] Train Loss: 0.1358 & Validation Loss: 0.5450
# EarlyStopping counter: 13 out of 20
# 64th Epoch starting.
# Epoch [64] Train Loss: 0.1320 & Validation Loss: 0.5665
# EarlyStopping counter: 14 out of 20
# 65th Epoch starting.
# Epoch [65] Train Loss: 0.1370 & Validation Loss: 0.5451
# EarlyStopping counter: 15 out of 20
# 66th Epoch starting.
# Epoch [66] Train Loss: 0.1190 & Validation Loss: 0.5367
# EarlyStopping counter: 16 out of 20
# 67th Epoch starting.
# Epoch [67] Train Loss: 0.1305 & Validation Loss: 0.4890
# EarlyStopping counter: 17 out of 20
# 68th Epoch starting.
# Epoch [68] Train Loss: 0.1113 & Validation Loss: 0.5257
# EarlyStopping counter: 18 out of 20
# 69th Epoch starting.
# Epoch [69] Train Loss: 0.1253 & Validation Loss: 0.5367
# EarlyStopping counter: 19 out of 20
# 70th Epoch starting.
# Epoch [70] Train Loss: 0.1117 & Validation Loss: 0.5687
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 2 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 0.8079 & Validation Loss: 0.5555
# Validation loss decreased (inf --> 0.5555).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 2.3431 & Validation Loss: 2.3026
# EarlyStopping counter: 1 out of 20
# 3th Epoch starting.
# Epoch [3] Train Loss: 2.3027 & Validation Loss: 2.3027
# EarlyStopping counter: 2 out of 20
# 4th Epoch starting.
# Epoch [4] Train Loss: 2.3027 & Validation Loss: 2.3027
# EarlyStopping counter: 3 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 2.3027 & Validation Loss: 2.3028
# EarlyStopping counter: 4 out of 20
# 6th Epoch starting.
# Epoch [6] Train Loss: 2.3027 & Validation Loss: 2.3028
# EarlyStopping counter: 5 out of 20
# 7th Epoch starting.
# Epoch [7] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 6 out of 20
# 8th Epoch starting.
# Epoch [8] Train Loss: 2.3027 & Validation Loss: 2.3028
# EarlyStopping counter: 7 out of 20
# 9th Epoch starting.
# Epoch [9] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 8 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 9 out of 20
# 11th Epoch starting.
# Epoch [11] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 10 out of 20
# 12th Epoch starting.
# Epoch [12] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 11 out of 20
# 13th Epoch starting.
# Epoch [13] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 12 out of 20
# 14th Epoch starting.
# Epoch [14] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 13 out of 20
# 15th Epoch starting.
# Epoch [15] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 14 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 2.3027 & Validation Loss: 2.3028
# EarlyStopping counter: 15 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 16 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 2.3027 & Validation Loss: 2.3029
# EarlyStopping counter: 17 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 2.3027 & Validation Loss: 2.3028
# EarlyStopping counter: 18 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 19 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 2.3027 & Validation Loss: 2.3027
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 3 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 0.5990 & Validation Loss: 0.5645
# Validation loss decreased (inf --> 0.5645).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 2.3227 & Validation Loss: 2.3024
# EarlyStopping counter: 1 out of 20
# 3th Epoch starting.
# Epoch [3] Train Loss: 2.2995 & Validation Loss: 2.2913
# EarlyStopping counter: 2 out of 20
# 4th Epoch starting.
# Epoch [4] Train Loss: 2.2544 & Validation Loss: 2.2236
# EarlyStopping counter: 3 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 2.2177 & Validation Loss: 2.2061
# EarlyStopping counter: 4 out of 20
# 6th Epoch starting.
# Epoch [6] Train Loss: 2.1792 & Validation Loss: 2.1447
# EarlyStopping counter: 5 out of 20
# 7th Epoch starting.
# Epoch [7] Train Loss: 2.0740 & Validation Loss: 2.0839
# EarlyStopping counter: 6 out of 20
# 8th Epoch starting.
# Epoch [8] Train Loss: 2.0049 & Validation Loss: 1.9647
# EarlyStopping counter: 7 out of 20
# 9th Epoch starting.
# Epoch [9] Train Loss: 1.9380 & Validation Loss: 1.9000
# EarlyStopping counter: 8 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 1.8817 & Validation Loss: 1.8562
# EarlyStopping counter: 9 out of 20
# 11th Epoch starting.
# Epoch [11] Train Loss: 1.8218 & Validation Loss: 1.7813
# EarlyStopping counter: 10 out of 20
# 12th Epoch starting.
# Epoch [12] Train Loss: 1.7711 & Validation Loss: 1.8075
# EarlyStopping counter: 11 out of 20
# 13th Epoch starting.
# Epoch [13] Train Loss: 1.7264 & Validation Loss: 1.7081
# EarlyStopping counter: 12 out of 20
# 14th Epoch starting.
# Epoch [14] Train Loss: 1.7042 & Validation Loss: 1.6773
# EarlyStopping counter: 13 out of 20
# 15th Epoch starting.
# Epoch [15] Train Loss: 1.6711 & Validation Loss: 1.6334
# EarlyStopping counter: 14 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 1.6464 & Validation Loss: 1.6358
# EarlyStopping counter: 15 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 1.6151 & Validation Loss: 1.6248
# EarlyStopping counter: 16 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 1.5995 & Validation Loss: 1.5791
# EarlyStopping counter: 17 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 1.5683 & Validation Loss: 1.5990
# EarlyStopping counter: 18 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 1.5493 & Validation Loss: 1.5388
# EarlyStopping counter: 19 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 1.5115 & Validation Loss: 1.4922
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 4 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 0.5197 & Validation Loss: 0.6355
# Validation loss decreased (inf --> 0.6355).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 2.3077 & Validation Loss: 2.3027
# EarlyStopping counter: 1 out of 20
# 3th Epoch starting.
# Epoch [3] Train Loss: 2.3027 & Validation Loss: 2.3028
# EarlyStopping counter: 2 out of 20
# 4th Epoch starting.
# Epoch [4] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 3 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 4 out of 20
# 6th Epoch starting.
# Epoch [6] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 5 out of 20
# 7th Epoch starting.
# Epoch [7] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 6 out of 20
# 8th Epoch starting.
# Epoch [8] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 7 out of 20
# 9th Epoch starting.
# Epoch [9] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 8 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 9 out of 20
# 11th Epoch starting.
# Epoch [11] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 10 out of 20
# 12th Epoch starting.
# Epoch [12] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 11 out of 20
# 13th Epoch starting.
# Epoch [13] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 12 out of 20
# 14th Epoch starting.
# Epoch [14] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 13 out of 20
# 15th Epoch starting.
# Epoch [15] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 14 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 15 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 16 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 17 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 18 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 19 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 5 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 0.5035 & Validation Loss: 0.6047
# Validation loss decreased (inf --> 0.6047).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 2.2437 & Validation Loss: 2.2363
# EarlyStopping counter: 1 out of 20
# 3th Epoch starting.
# Epoch [3] Train Loss: 2.0336 & Validation Loss: 2.0369
# EarlyStopping counter: 2 out of 20
# 4th Epoch starting.
# Epoch [4] Train Loss: 1.9552 & Validation Loss: 1.9423
# EarlyStopping counter: 3 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 1.8681 & Validation Loss: 1.8866
# EarlyStopping counter: 4 out of 20
# 6th Epoch starting.
# Epoch [6] Train Loss: 1.7582 & Validation Loss: 1.6922
# EarlyStopping counter: 5 out of 20
# 7th Epoch starting.
# Epoch [7] Train Loss: 1.6883 & Validation Loss: 1.6346
# EarlyStopping counter: 6 out of 20
# 8th Epoch starting.
# Epoch [8] Train Loss: 1.6365 & Validation Loss: 1.6225
# EarlyStopping counter: 7 out of 20
# 9th Epoch starting.
# Epoch [9] Train Loss: 1.5945 & Validation Loss: 1.6204
# EarlyStopping counter: 8 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 1.5450 & Validation Loss: 1.5748
# EarlyStopping counter: 9 out of 20
# 11th Epoch starting.
# Epoch [11] Train Loss: 1.5016 & Validation Loss: 1.4604
# EarlyStopping counter: 10 out of 20
# 12th Epoch starting.
# Epoch [12] Train Loss: 1.4372 & Validation Loss: 1.3922
# EarlyStopping counter: 11 out of 20
# 13th Epoch starting.
# Epoch [13] Train Loss: 1.3864 & Validation Loss: 1.3372
# EarlyStopping counter: 12 out of 20
# 14th Epoch starting.
# Epoch [14] Train Loss: 1.3200 & Validation Loss: 1.3042
# EarlyStopping counter: 13 out of 20
# 15th Epoch starting.
# Epoch [15] Train Loss: 1.2725 & Validation Loss: 1.3021
# EarlyStopping counter: 14 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 1.2257 & Validation Loss: 1.2174
# EarlyStopping counter: 15 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 1.1848 & Validation Loss: 1.1583
# EarlyStopping counter: 16 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 1.1288 & Validation Loss: 1.1557
# EarlyStopping counter: 17 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 1.0778 & Validation Loss: 1.0575
# EarlyStopping counter: 18 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 1.0376 & Validation Loss: 1.1009
# EarlyStopping counter: 19 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 0.9994 & Validation Loss: 0.9876
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 15682.345513343811

# %%
 test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False,
                                transform=transforms.ToTensor(),
                                download=True) 

test_loader = torch.utils.data.DataLoader(test_dataset,
                                          batch_size=batch_size,
                                          num_workers=0)
# Out:
# Files already downloaded and verified

# %%
test_model(model)
# Out:
# [Test set] Average loss: 0.0024, Accuracy: 8046/10000 (80.46%)
