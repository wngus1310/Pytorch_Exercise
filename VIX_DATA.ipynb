# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import FinanceDataReader as fdr

# %matplotlib inline

plt.rcParams["figure.figsize"] = (14,8)
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 2
plt.rcParams["axes.grid"] = True
plt.rcParams['axes.axisbelow'] = True

# %%
import FinanceDataReader as fdr

vx = fdr.DataReader('VX', '2000-01-01') # S&P 500 VIX
vx.iloc[-5:]
# Out:
#             Close   Open   High    Low    Volume  Change
# Date
# 2020-12-18  24.17  23.86  25.00  23.80   55630.0  0.0147
# 2020-12-21  26.33  24.20  27.85  23.95  107670.0  0.0889
# 2020-12-22  25.77  26.25  27.10  25.60   50930.0 -0.0209
# 2020-12-23  24.63  25.80  26.50  24.10   48020.0 -0.0446
# 2020-12-24  23.83  24.60  24.67  23.80   20750.0 -0.0325

# %%
vx.head()
# Out:
#             Close   Open   High    Low   Volume  Change
# Date
# 2012-04-19  20.40  20.55  21.15  19.87  38540.0 -0.0061
# 2012-04-20  19.70  20.10  20.15  19.60  30800.0 -0.0343
# 2012-04-23  20.60  20.45  21.40  20.40  37080.0  0.0457
# 2012-04-24  19.75  20.40  20.80  19.70  24600.0 -0.0413
# 2012-04-25  18.55  19.40  19.45  18.50  37960.0 -0.0608

# %%
vx['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# * VIX data 불러오는데 오류 있음
