# %%
# !pip install torch_optimizer

import numpy as np
import random
import math
import time
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

from torch.optim import Optimizer
import torch_optimizer as optim

from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler

from torchvision import datasets
from torchvision.transforms import transforms

import torch.nn.functional as F


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
name = torch.cuda.get_device_name(0)
print("GPU: " + name)

random_seed = 0

torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

np.random.seed(random_seed)
random.seed(random_seed)


class EarlyStopping:
    def __init__(self, patience=10, path='checkpoint.pt'):
        
        self.patience = patience
        self.counter = 0
        self.best_score = None
        self.val_loss_min = np.Inf
        self.early_stop = False

        self.path = path



    def __call__(self, val_loss, model):

        score = val_loss

        if self.best_score is None:
            self.best_score = score
            
            print('Validation loss decreased ({:.4f} --> {:.4f}).  Saving model ...'.format(self.val_loss_min, val_loss))
            torch.save(model.state_dict(), self.path)
            self.val_loss_min = val_loss

        elif score > self.best_score:
            self.counter += 1
            print("EarlyStopping counter: {} out of {}".format(self.counter, self.patience))

            if self.counter >= self.patience:
                self.early_stop = True

        else:
            self.best_score = score
            self.counter = 0

            print('Validation loss decreased --- Saving model ...')
            torch.save(model.state_dict(), self.path)
            self.val_loss_min = val_loss



def get_data_len_index(pad=4, randomcrop=32):
    data_shuffle = []

    transform = transforms.Compose([
                                    transforms.Pad(pad),
                                    transforms.RandomHorizontalFlip(),
                                    transforms.RandomCrop(randomcrop),
                                    transforms.ToTensor()
    ])

    train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                     train=True,
                                     transform=transform,
                                     download=True) 
    
    len_train = len(train_dataset)
    index_train = list(range(len_train))
    

    data_shuffle.append(len_train)
    data_shuffle.append(index_train)
    data_shuffle.append(train_dataset)

    return data_shuffle



def test_model(model, batch_size=128):
    model.eval()
    test_loss, correct, total = 0, 0, 0

    with torch.no_grad():
        for images, labels in test_loader :
            images, labels = images.to(device), labels.to(device)

            output = model(images)
            test_loss += loss_function(output, labels).item()

            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(labels.view_as(pred)).sum().item()

            total += labels.size(0)

    print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
            test_loss /total, correct, total,
            100. * correct / total))
    

def train_model(model, batch_size, n_epochs, patience, loader):
    train_loader = loader[0]
    valid_loader = loader[1]
    
    train_losses = []
    valid_losses = []

    avg_train_losses = []
    avg_valid_losses = []

    early_stopping = EarlyStopping(patience=patience)

    model.train()

    start = time.time()

    for epoch in range(1,n_epochs+1):
        print("{}th Epoch starting.".format(epoch))

        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()

            output = model(images)

            train_loss = loss_function(output, labels)

            train_loss.backward()

            optimizer.step()

            loss = train_loss.item()


            train_losses.append(loss)


        model.eval()

        with torch.no_grad():
            for images, labels in valid_loader:
                images , labels = images.to(device), labels.to(device)

                output = model(images)

                valid_loss = loss_function(output, labels)

                loss = valid_loss.item()

                valid_losses.append(loss)
        
        loss_train = np.average(train_losses)
        loss_valid = np.average(valid_losses)

        avg_train_losses.append(loss_train)
        avg_valid_losses.append(loss_valid)

        print("Epoch [{}] Train Loss: {:.4f} & Validation Loss: {:.4f}".format(epoch, loss_train, loss_valid))

        train_losses = []
        valid_losses = []

        early_stopping(loss_valid, model)

        if early_stopping.early_stop:
            print("Early Stopping!!")
            end = time.time()
            #print(end-start)
            break

    model.load_state_dict(torch.load('checkpoint.pt'))

    return model, avg_train_losses, avg_valid_losses



def train_KFold(model, batch_size, n_epochs, patience, data_info, fold):
        
    train_losses = []
    valid_losses = []

    loader = []

    path='checkpoint.pt'

    len_train = data_info[0]
    index_train = data_info[1]
    train_dataset = data_info[2]

    np.random.shuffle(index_train)

    split_size = len_train // fold

    start = time.time()
    for i in range(fold):

        valid_ind = index_train[split_size * i: split_size * (i+1)]
                
        if i == 0:
            train_ind = index_train[split_size * (i+1):]
                    
        elif i == (fold-1):
            train_ind = index_train[:split_size*i]

        else:
            train_ind = index_train[:split_size * i] + index_train[split_size * (i+1):]

        train_sampler = SubsetRandomSampler(train_ind)
        valid_sampler = SubsetRandomSampler(valid_ind)    

        train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                                        batch_size=batch_size,
                                                        sampler = train_sampler,
                                                        num_workers=0)
                
        valid_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                                        batch_size=batch_size,
                                                        sampler = valid_sampler,
                                                        num_workers=0)
        
        loader.append(train_loader)
        loader.append(valid_loader)
                

        print("{} Fold is Training".format(i+1))

        model, avg_train_losses, avg_valid_losses = train_model(model, batch_size, n_epochs, patience, loader)
        
        train_losses.append(avg_train_losses)
        valid_losses.append(avg_valid_losses)
        
    end = time.time()

    print(end-start)

    return model, train_losses, valid_losses
# Out:
# Collecting torch_optimizer
#   Downloading https://files.pythonhosted.org/packages/ce/70/ca0cd259662eef5c9448d3ecf14af880bbfe76331e4eeab7b19827d6dbe6/torch_optimizer-0.0.1a17-py3-none-any.whl (69kB)
#      |████████████████████████████████| 71kB 6.1MB/s
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from torch_optimizer) (1.7.0+cu101)
# Collecting pytorch-ranger>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/0d/70/12256257d861bbc3e176130d25be1de085ce7a9e60594064888a950f2154/pytorch_ranger-0.1.1-py3-none-any.whl
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->torch_optimizer) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->torch_optimizer) (1.19.4)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->torch_optimizer) (0.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->torch_optimizer) (0.16.0)
# Installing collected packages: pytorch-ranger, torch-optimizer
# Successfully installed pytorch-ranger-0.1.1 torch-optimizer-0.0.1a17
# cuda:0
# GPU: Tesla T4

# %%
class VGG13_32(nn.Module) :
    def __init__(self) :
        super(VGG13_32, self).__init__()
        
        self.conv_layer1 = nn.Sequential(
                nn.BatchNorm2d(3),                              # Normalize the Input
                nn.Conv2d(3, 64, kernel_size=3, padding=1),     # 64 * 32 * 32
                nn.BatchNorm2d(64),     
                nn.ReLU(),
                nn.Conv2d(64, 64, kernel_size=3, padding=1),
                nn.BatchNorm2d(64),
                nn.ReLU(),                                      # 64 * 32 * 32
                nn.MaxPool2d(kernel_size=2, stride=2)           # 64 * 16 * 16
                )
        self.conv_layer2 = nn.Sequential(
                nn.Conv2d(64, 128, kernel_size=3, padding=1),   # 128 * 16 * 16
                nn.BatchNorm2d(128),   
                nn.ReLU(),
                nn.Conv2d(128, 128, kernel_size=3, padding=1),  # 128 * 16 * 16
                nn.BatchNorm2d(128), 
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 128 * 8 * 8
                )
        self.conv_layer3 = nn.Sequential(
                nn.Conv2d(128, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.BatchNorm2d(256),  
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.BatchNorm2d(256),  
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.BatchNorm2d(256),  
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 256 * 4 * 4
                )
        self.conv_layer4 = nn.Sequential(
                nn.Conv2d(256, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.BatchNorm2d(512),  
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.BatchNorm2d(512),  
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.BatchNorm2d(512),  
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2),          # 512 * 2 * 2
                )
        self.fc_layer1 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(512*2*2, 4096),                           # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer2 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(4096, 1024),                          # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer3 = nn.Sequential(
                nn.Linear(1024, 10),                     # 1 * num_class
                )

    def forward(self, x) :
        output = self.conv_layer1(x)
        output = self.conv_layer2(output)
        output = self.conv_layer3(output)
        output = self.conv_layer4(output)
        output = output.view(-1, 512*2*2)
        output = self.fc_layer1(output)
        output = self.fc_layer2(output)
        output = self.fc_layer3(output)
        return output

# %%
import torch.nn.init as init

def weight_init(m):
  if isinstance(m, nn.Conv2d):
    init.kaiming_uniform_(m.weight.data)

# %%
class VGG13_32_2(nn.Module) :
    def __init__(self) :
        super(VGG13_32_2, self).__init__()
        
        self.conv_layer1 = nn.Sequential(
                nn.BatchNorm2d(3),                              # Normalize the Input
                nn.Conv2d(3, 64, kernel_size=3, padding=1),     # 64 * 32 * 32
                nn.BatchNorm2d(64),     
                nn.ReLU(),
                nn.Conv2d(64, 64, kernel_size=3, padding=1),
                nn.BatchNorm2d(64),
                nn.ReLU(),                                      # 64 * 32 * 32
                nn.MaxPool2d(kernel_size=2, stride=2)           # 64 * 16 * 16
                )
        self.conv_layer2 = nn.Sequential(
                nn.Conv2d(64, 128, kernel_size=3, padding=1),   # 128 * 16 * 16
                nn.BatchNorm2d(128),   
                nn.ReLU(),
                nn.Conv2d(128, 128, kernel_size=3, padding=1),  # 128 * 16 * 16
                nn.BatchNorm2d(128), 
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 128 * 8 * 8
                )
        self.conv_layer3 = nn.Sequential(
                nn.Conv2d(128, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.BatchNorm2d(256),  
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.BatchNorm2d(256),  
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.BatchNorm2d(256),  
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 256 * 4 * 4
                )
        self.conv_layer4 = nn.Sequential(
                nn.Conv2d(256, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.BatchNorm2d(512),  
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.BatchNorm2d(512),  
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.BatchNorm2d(512),  
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2),          # 512 * 2 * 2
                )
        self.fc_layer1 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(512*2*2, 4096),                           # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer2 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(4096, 4096),                          # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer3 = nn.Sequential(
                nn.Linear(4096, 10),                     # 1 * num_class
                )

    def forward(self, x) :
        output = self.conv_layer1(x)
        output = self.conv_layer2(output)
        output = self.conv_layer3(output)
        output = self.conv_layer4(output)
        output = output.view(-1, 512*2*2)
        output = self.fc_layer1(output)
        output = self.fc_layer2(output)
        output = self.fc_layer3(output)
        return output

# %%
data_info = get_data_len_index()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar_10data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./cifar_10data/cifar-10-python.tar.gz to ./cifar_10data/

# %% [markdown]
# ### Change FC 4096 layer
# 4096 --> 1048 -->  10
#
# ### He Uniform Initialization

# %% [markdown]
# ### Batch_size 63 --> 256
# ### Weight_decay 5e-4 --> 5e-5

# %%
model = VGG13_32().to(device)
model.apply(weight_init)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = optim.RAdam(model.parameters(), weight_decay=5e-5)
batch_size = 256

# %%
model, train_losses, valid_losses = train_KFold(model, batch_size=batch_size, n_epochs=250, patience=20, data_info=data_info, fold=5)
# Out:
# 1 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 1.7446 & Validation Loss: 1.6394
# Validation loss decreased (inf --> 1.6394).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 2.0726 & Validation Loss: 1.9270
# EarlyStopping counter: 1 out of 20
# 3th Epoch starting.
# Epoch [3] Train Loss: 1.6171 & Validation Loss: 1.5772
# Validation loss decreased --- Saving model ...
# 4th Epoch starting.
# Epoch [4] Train Loss: 1.3981 & Validation Loss: 1.3879
# Validation loss decreased --- Saving model ...
# 5th Epoch starting.
# Epoch [5] Train Loss: 1.2343 & Validation Loss: 1.1792
# Validation loss decreased --- Saving model ...
# 6th Epoch starting.
# Epoch [6] Train Loss: 1.0960 & Validation Loss: 1.2180
# EarlyStopping counter: 1 out of 20
# 7th Epoch starting.
# Epoch [7] Train Loss: 0.9865 & Validation Loss: 1.0754
# Validation loss decreased --- Saving model ...
# 8th Epoch starting.
# Epoch [8] Train Loss: 0.8844 & Validation Loss: 0.8955
# Validation loss decreased --- Saving model ...
# 9th Epoch starting.
# Epoch [9] Train Loss: 0.8058 & Validation Loss: 0.7819
# Validation loss decreased --- Saving model ...
# 10th Epoch starting.
# Epoch [10] Train Loss: 0.7322 & Validation Loss: 0.7751
# Validation loss decreased --- Saving model ...
# 11th Epoch starting.
# Epoch [11] Train Loss: 0.6835 & Validation Loss: 0.7521
# Validation loss decreased --- Saving model ...
# 12th Epoch starting.
# Epoch [12] Train Loss: 0.6297 & Validation Loss: 0.7128
# Validation loss decreased --- Saving model ...
# 13th Epoch starting.
# Epoch [13] Train Loss: 0.5949 & Validation Loss: 0.6764
# Validation loss decreased --- Saving model ...
# 14th Epoch starting.
# Epoch [14] Train Loss: 0.5582 & Validation Loss: 0.6416
# Validation loss decreased --- Saving model ...
# 15th Epoch starting.
# Epoch [15] Train Loss: 0.5188 & Validation Loss: 0.5946
# Validation loss decreased --- Saving model ...
# 16th Epoch starting.
# Epoch [16] Train Loss: 0.4901 & Validation Loss: 0.5619
# Validation loss decreased --- Saving model ...
# 17th Epoch starting.
# Epoch [17] Train Loss: 0.4564 & Validation Loss: 0.5766
# EarlyStopping counter: 1 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 0.4386 & Validation Loss: 0.6011
# EarlyStopping counter: 2 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 0.4281 & Validation Loss: 0.6672
# EarlyStopping counter: 3 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 0.4049 & Validation Loss: 0.5401
# Validation loss decreased --- Saving model ...
# 21th Epoch starting.
# Epoch [21] Train Loss: 0.3815 & Validation Loss: 0.5429
# EarlyStopping counter: 1 out of 20
# 22th Epoch starting.
# Epoch [22] Train Loss: 0.3714 & Validation Loss: 0.5985
# EarlyStopping counter: 2 out of 20
# 23th Epoch starting.
# Epoch [23] Train Loss: 0.3507 & Validation Loss: 0.5589
# EarlyStopping counter: 3 out of 20
# 24th Epoch starting.
# Epoch [24] Train Loss: 0.3493 & Validation Loss: 0.5846
# EarlyStopping counter: 4 out of 20
# 25th Epoch starting.
# Epoch [25] Train Loss: 0.3315 & Validation Loss: 0.4823
# Validation loss decreased --- Saving model ...
# 26th Epoch starting.
# Epoch [26] Train Loss: 0.3123 & Validation Loss: 0.5351
# EarlyStopping counter: 1 out of 20
# 27th Epoch starting.
# Epoch [27] Train Loss: 0.3013 & Validation Loss: 0.5283
# EarlyStopping counter: 2 out of 20
# 28th Epoch starting.
# Epoch [28] Train Loss: 0.2988 & Validation Loss: 0.5305
# EarlyStopping counter: 3 out of 20
# 29th Epoch starting.
# Epoch [29] Train Loss: 0.2723 & Validation Loss: 0.5416
# EarlyStopping counter: 4 out of 20
# 30th Epoch starting.
# Epoch [30] Train Loss: 0.2752 & Validation Loss: 0.5398
# EarlyStopping counter: 5 out of 20
# 31th Epoch starting.
# Epoch [31] Train Loss: 0.2629 & Validation Loss: 0.5249
# EarlyStopping counter: 6 out of 20
# 32th Epoch starting.
# Epoch [32] Train Loss: 0.2582 & Validation Loss: 0.5959
# EarlyStopping counter: 7 out of 20
# 33th Epoch starting.
# Epoch [33] Train Loss: 0.2463 & Validation Loss: 0.5162
# EarlyStopping counter: 8 out of 20
# 34th Epoch starting.
# Epoch [34] Train Loss: 0.2431 & Validation Loss: 0.5641
# EarlyStopping counter: 9 out of 20
# 35th Epoch starting.
# Epoch [35] Train Loss: 0.2318 & Validation Loss: 0.5338
# EarlyStopping counter: 10 out of 20
# 36th Epoch starting.
# Epoch [36] Train Loss: 0.2235 & Validation Loss: 0.5239
# EarlyStopping counter: 11 out of 20
# 37th Epoch starting.
# Epoch [37] Train Loss: 0.2345 & Validation Loss: 0.5257
# EarlyStopping counter: 12 out of 20
# 38th Epoch starting.
# Epoch [38] Train Loss: 0.2165 & Validation Loss: 0.5812
# EarlyStopping counter: 13 out of 20
# 39th Epoch starting.
# Epoch [39] Train Loss: 0.2109 & Validation Loss: 0.5128
# EarlyStopping counter: 14 out of 20
# 40th Epoch starting.
# Epoch [40] Train Loss: 0.2004 & Validation Loss: 0.5428
# EarlyStopping counter: 15 out of 20
# 41th Epoch starting.
# Epoch [41] Train Loss: 0.1893 & Validation Loss: 0.5431
# EarlyStopping counter: 16 out of 20
# 42th Epoch starting.
# Epoch [42] Train Loss: 0.1833 & Validation Loss: 0.5306
# EarlyStopping counter: 17 out of 20
# 43th Epoch starting.
# Epoch [43] Train Loss: 0.1913 & Validation Loss: 0.6295
# EarlyStopping counter: 18 out of 20
# 44th Epoch starting.
# Epoch [44] Train Loss: 0.1873 & Validation Loss: 0.5502
# EarlyStopping counter: 19 out of 20
# 45th Epoch starting.
# Epoch [45] Train Loss: 0.1708 & Validation Loss: 0.5337
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 2 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 0.8327 & Validation Loss: 0.6088
# Validation loss decreased (inf --> 0.6088).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 2.2662 & Validation Loss: 2.3025
# EarlyStopping counter: 1 out of 20
# 3th Epoch starting.
# Epoch [3] Train Loss: 2.3027 & Validation Loss: 2.3026
# EarlyStopping counter: 2 out of 20
# 4th Epoch starting.
# Epoch [4] Train Loss: 2.3027 & Validation Loss: 2.3027
# EarlyStopping counter: 3 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 4 out of 20
# 6th Epoch starting.
# Epoch [6] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 5 out of 20
# 7th Epoch starting.
# Epoch [7] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 6 out of 20
# 8th Epoch starting.
# Epoch [8] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 7 out of 20
# 9th Epoch starting.
# Epoch [9] Train Loss: 2.3027 & Validation Loss: 2.3029
# EarlyStopping counter: 8 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 9 out of 20
# 11th Epoch starting.
# Epoch [11] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 10 out of 20
# 12th Epoch starting.
# Epoch [12] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 11 out of 20
# 13th Epoch starting.
# Epoch [13] Train Loss: 2.3027 & Validation Loss: 2.3028
# EarlyStopping counter: 12 out of 20
# 14th Epoch starting.
# Epoch [14] Train Loss: 2.3027 & Validation Loss: 2.3028
# EarlyStopping counter: 13 out of 20
# 15th Epoch starting.
# Epoch [15] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 14 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 15 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 16 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 17 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 18 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 19 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 2.3027 & Validation Loss: 2.3027
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 3 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 0.7344 & Validation Loss: 0.8966
# Validation loss decreased (inf --> 0.8966).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 2.4684 & Validation Loss: 2.3025
# EarlyStopping counter: 1 out of 20
# 3th Epoch starting.
# Epoch [3] Train Loss: 2.3028 & Validation Loss: 2.3026
# EarlyStopping counter: 2 out of 20
# 4th Epoch starting.
# Epoch [4] Train Loss: 2.3027 & Validation Loss: 2.3027
# EarlyStopping counter: 3 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 4 out of 20
# 6th Epoch starting.
# Epoch [6] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 5 out of 20
# 7th Epoch starting.
# Epoch [7] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 6 out of 20
# 8th Epoch starting.
# Epoch [8] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 7 out of 20
# 9th Epoch starting.
# Epoch [9] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 8 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 2.3026 & Validation Loss: 2.3029
# EarlyStopping counter: 9 out of 20
# 11th Epoch starting.
# Epoch [11] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 10 out of 20
# 12th Epoch starting.
# Epoch [12] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 11 out of 20
# 13th Epoch starting.
# Epoch [13] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 12 out of 20
# 14th Epoch starting.
# Epoch [14] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 13 out of 20
# 15th Epoch starting.
# Epoch [15] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 14 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 2.3026 & Validation Loss: 2.3029
# EarlyStopping counter: 15 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 16 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 17 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 2.3027 & Validation Loss: 2.3028
# EarlyStopping counter: 18 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 19 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 4 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 0.7002 & Validation Loss: 0.6365
# Validation loss decreased (inf --> 0.6365).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 2.3091 & Validation Loss: 2.3025
# EarlyStopping counter: 1 out of 20
# 3th Epoch starting.
# Epoch [3] Train Loss: 2.3028 & Validation Loss: 2.3026
# EarlyStopping counter: 2 out of 20
# 4th Epoch starting.
# Epoch [4] Train Loss: 2.3027 & Validation Loss: 2.3026
# EarlyStopping counter: 3 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 4 out of 20
# 6th Epoch starting.
# Epoch [6] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 5 out of 20
# 7th Epoch starting.
# Epoch [7] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 6 out of 20
# 8th Epoch starting.
# Epoch [8] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 7 out of 20
# 9th Epoch starting.
# Epoch [9] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 8 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 9 out of 20
# 11th Epoch starting.
# Epoch [11] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 10 out of 20
# 12th Epoch starting.
# Epoch [12] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 11 out of 20
# 13th Epoch starting.
# Epoch [13] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 12 out of 20
# 14th Epoch starting.
# Epoch [14] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 13 out of 20
# 15th Epoch starting.
# Epoch [15] Train Loss: 2.3027 & Validation Loss: 2.3028
# EarlyStopping counter: 14 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 15 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 16 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 17 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 2.3027 & Validation Loss: 2.3028
# EarlyStopping counter: 18 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 19 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 2.3026 & Validation Loss: 2.3029
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 5 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 0.6219 & Validation Loss: 0.6214
# Validation loss decreased (inf --> 0.6214).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 2.2930 & Validation Loss: 2.3027
# EarlyStopping counter: 1 out of 20
# 3th Epoch starting.
# Epoch [3] Train Loss: 2.3028 & Validation Loss: 2.3027
# EarlyStopping counter: 2 out of 20
# 4th Epoch starting.
# Epoch [4] Train Loss: 2.3027 & Validation Loss: 2.3027
# EarlyStopping counter: 3 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 4 out of 20
# 6th Epoch starting.
# Epoch [6] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 5 out of 20
# 7th Epoch starting.
# Epoch [7] Train Loss: 2.3027 & Validation Loss: 2.3029
# EarlyStopping counter: 6 out of 20
# 8th Epoch starting.
# Epoch [8] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 7 out of 20
# 9th Epoch starting.
# Epoch [9] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 8 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 9 out of 20
# 11th Epoch starting.
# Epoch [11] Train Loss: 2.3027 & Validation Loss: 2.3028
# EarlyStopping counter: 10 out of 20
# 12th Epoch starting.
# Epoch [12] Train Loss: 2.3027 & Validation Loss: 2.3029
# EarlyStopping counter: 11 out of 20
# 13th Epoch starting.
# Epoch [13] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 12 out of 20
# 14th Epoch starting.
# Epoch [14] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 13 out of 20
# 15th Epoch starting.
# Epoch [15] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 14 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 15 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 16 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 2.3026 & Validation Loss: 2.3029
# EarlyStopping counter: 17 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 18 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 2.3026 & Validation Loss: 2.3027
# EarlyStopping counter: 19 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 2.3026 & Validation Loss: 2.3028
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 4282.99987578392

# %%
 test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False,
                                transform=transforms.ToTensor(),
                                download=True) 

test_loader = torch.utils.data.DataLoader(test_dataset,
                                          batch_size=batch_size,
                                          num_workers=0)
# Out:
# Files already downloaded and verified

# %%
test_model(model)
# Out:
# [Test set] Average loss: 0.0025, Accuracy: 7962/10000 (79.62%)

# %% [markdown]
# ### Base Model
# #### batch_size = 128
# #### He
# #### noweight_decay

# %%
model = VGG13_32_2().to(device)
model.apply(weight_init)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = optim.RAdam(model.parameters())
batch_size = 128

# %%
model, train_losses, valid_losses = train_KFold(model, batch_size=batch_size, n_epochs=250, patience=20, data_info=data_info, fold=5)
# Out:
# 1 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 1.6348 & Validation Loss: 1.3335
# Validation loss decreased (inf --> 1.3335).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 2.2022 & Validation Loss: 1.9265
# EarlyStopping counter: 1 out of 20
# 3th Epoch starting.
# Epoch [3] Train Loss: 1.8511 & Validation Loss: 1.8259
# EarlyStopping counter: 2 out of 20
# 4th Epoch starting.
# Epoch [4] Train Loss: 1.6147 & Validation Loss: 1.5371
# EarlyStopping counter: 3 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 1.3622 & Validation Loss: 1.2939
# Validation loss decreased --- Saving model ...
# 6th Epoch starting.
# Epoch [6] Train Loss: 1.1781 & Validation Loss: 1.0677
# Validation loss decreased --- Saving model ...
# 7th Epoch starting.
# Epoch [7] Train Loss: 1.0257 & Validation Loss: 1.0474
# Validation loss decreased --- Saving model ...
# 8th Epoch starting.
# Epoch [8] Train Loss: 0.9273 & Validation Loss: 0.9060
# Validation loss decreased --- Saving model ...
# 9th Epoch starting.
# Epoch [9] Train Loss: 0.8381 & Validation Loss: 0.8182
# Validation loss decreased --- Saving model ...
# 10th Epoch starting.
# Epoch [10] Train Loss: 0.7659 & Validation Loss: 0.7771
# Validation loss decreased --- Saving model ...
# 11th Epoch starting.
# Epoch [11] Train Loss: 0.7007 & Validation Loss: 0.7379
# Validation loss decreased --- Saving model ...
# 12th Epoch starting.
# Epoch [12] Train Loss: 0.6447 & Validation Loss: 0.6968
# Validation loss decreased --- Saving model ...
# 13th Epoch starting.
# Epoch [13] Train Loss: 0.5993 & Validation Loss: 0.6320
# Validation loss decreased --- Saving model ...
# 14th Epoch starting.
# Epoch [14] Train Loss: 0.5546 & Validation Loss: 0.6015
# Validation loss decreased --- Saving model ...
# 15th Epoch starting.
# Epoch [15] Train Loss: 0.5252 & Validation Loss: 0.5919
# Validation loss decreased --- Saving model ...
# 16th Epoch starting.
# Epoch [16] Train Loss: 0.5010 & Validation Loss: 0.5866
# Validation loss decreased --- Saving model ...
# 17th Epoch starting.
# Epoch [17] Train Loss: 0.4681 & Validation Loss: 0.5963
# EarlyStopping counter: 1 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 0.4532 & Validation Loss: 0.5829
# Validation loss decreased --- Saving model ...
# 19th Epoch starting.
# Epoch [19] Train Loss: 0.4181 & Validation Loss: 0.5945
# EarlyStopping counter: 1 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 0.4056 & Validation Loss: 0.5429
# Validation loss decreased --- Saving model ...
# 21th Epoch starting.
# Epoch [21] Train Loss: 0.3880 & Validation Loss: 0.5330
# Validation loss decreased --- Saving model ...
# 22th Epoch starting.
# Epoch [22] Train Loss: 0.3637 & Validation Loss: 0.5304
# Validation loss decreased --- Saving model ...
# 23th Epoch starting.
# Epoch [23] Train Loss: 0.3548 & Validation Loss: 0.5523
# EarlyStopping counter: 1 out of 20
# 24th Epoch starting.
# Epoch [24] Train Loss: 0.3396 & Validation Loss: 0.5144
# Validation loss decreased --- Saving model ...
# 25th Epoch starting.
# Epoch [25] Train Loss: 0.3296 & Validation Loss: 0.4716
# Validation loss decreased --- Saving model ...
# 26th Epoch starting.
# Epoch [26] Train Loss: 0.3051 & Validation Loss: 0.5144
# EarlyStopping counter: 1 out of 20
# 27th Epoch starting.
# Epoch [27] Train Loss: 0.3116 & Validation Loss: 0.4832
# EarlyStopping counter: 2 out of 20
# 28th Epoch starting.
# Epoch [28] Train Loss: 0.2934 & Validation Loss: 0.5372
# EarlyStopping counter: 3 out of 20
# 29th Epoch starting.
# Epoch [29] Train Loss: 0.2853 & Validation Loss: 0.4701
# Validation loss decreased --- Saving model ...
# 30th Epoch starting.
# Epoch [30] Train Loss: 0.2723 & Validation Loss: 0.4827
# EarlyStopping counter: 1 out of 20
# 31th Epoch starting.
# Epoch [31] Train Loss: 0.2713 & Validation Loss: 0.4857
# EarlyStopping counter: 2 out of 20
# 32th Epoch starting.
# Epoch [32] Train Loss: 0.2552 & Validation Loss: 0.5062
# EarlyStopping counter: 3 out of 20
# 33th Epoch starting.
# Epoch [33] Train Loss: 0.2454 & Validation Loss: 0.4916
# EarlyStopping counter: 4 out of 20
# 34th Epoch starting.
# Epoch [34] Train Loss: 0.2460 & Validation Loss: 0.4691
# Validation loss decreased --- Saving model ...
# 35th Epoch starting.
# Epoch [35] Train Loss: 0.2324 & Validation Loss: 0.4647
# Validation loss decreased --- Saving model ...
# 36th Epoch starting.
# Epoch [36] Train Loss: 0.2261 & Validation Loss: 0.4961
# EarlyStopping counter: 1 out of 20
# 37th Epoch starting.
# Epoch [37] Train Loss: 0.2202 & Validation Loss: 0.4578
# Validation loss decreased --- Saving model ...
# 38th Epoch starting.
# Epoch [38] Train Loss: 0.2145 & Validation Loss: 0.5600
# EarlyStopping counter: 1 out of 20
# 39th Epoch starting.
# Epoch [39] Train Loss: 0.2128 & Validation Loss: 0.4917
# EarlyStopping counter: 2 out of 20
# 40th Epoch starting.
# Epoch [40] Train Loss: 0.1996 & Validation Loss: 0.5333
# EarlyStopping counter: 3 out of 20
# 41th Epoch starting.
# Epoch [41] Train Loss: 0.2032 & Validation Loss: 0.5420
# EarlyStopping counter: 4 out of 20
# 42th Epoch starting.
# Epoch [42] Train Loss: 0.1944 & Validation Loss: 0.5037
# EarlyStopping counter: 5 out of 20
# 43th Epoch starting.
# Epoch [43] Train Loss: 0.1888 & Validation Loss: 0.5035
# EarlyStopping counter: 6 out of 20
# 44th Epoch starting.
# Epoch [44] Train Loss: 0.1823 & Validation Loss: 0.4853
# EarlyStopping counter: 7 out of 20
# 45th Epoch starting.
# Epoch [45] Train Loss: 0.1779 & Validation Loss: 0.5246
# EarlyStopping counter: 8 out of 20
# 46th Epoch starting.
# Epoch [46] Train Loss: 0.1842 & Validation Loss: 0.4722
# EarlyStopping counter: 9 out of 20
# 47th Epoch starting.
# Epoch [47] Train Loss: 0.1644 & Validation Loss: 0.4967
# EarlyStopping counter: 10 out of 20
# 48th Epoch starting.
# Epoch [48] Train Loss: 0.1675 & Validation Loss: 0.4996
# EarlyStopping counter: 11 out of 20
# 49th Epoch starting.
# Epoch [49] Train Loss: 0.1648 & Validation Loss: 0.5101
# EarlyStopping counter: 12 out of 20
# 50th Epoch starting.
# Epoch [50] Train Loss: 0.1566 & Validation Loss: 0.5758
# EarlyStopping counter: 13 out of 20
# 51th Epoch starting.
# Epoch [51] Train Loss: 0.1526 & Validation Loss: 0.5019
# EarlyStopping counter: 14 out of 20
# 52th Epoch starting.
# Epoch [52] Train Loss: 0.1412 & Validation Loss: 0.5032
# EarlyStopping counter: 15 out of 20
# 53th Epoch starting.
# Epoch [53] Train Loss: 0.1556 & Validation Loss: 0.5593
# EarlyStopping counter: 16 out of 20
# 54th Epoch starting.
# Epoch [54] Train Loss: 0.1469 & Validation Loss: 0.5467
# EarlyStopping counter: 17 out of 20
# 55th Epoch starting.
# Epoch [55] Train Loss: 0.1470 & Validation Loss: 0.5493
# EarlyStopping counter: 18 out of 20
# 56th Epoch starting.
# Epoch [56] Train Loss: 0.1396 & Validation Loss: 0.5015
# EarlyStopping counter: 19 out of 20
# 57th Epoch starting.
# Epoch [57] Train Loss: 0.1404 & Validation Loss: 0.5004
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 2 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 1.6403 & Validation Loss: 1.3134
# Validation loss decreased (inf --> 1.3134).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 1.0018 & Validation Loss: 0.9220
# Validation loss decreased --- Saving model ...
# 3th Epoch starting.
# Epoch [3] Train Loss: 0.6861 & Validation Loss: 0.6810
# Validation loss decreased --- Saving model ...
# 4th Epoch starting.
# Epoch [4] Train Loss: 0.5250 & Validation Loss: 0.7602
# EarlyStopping counter: 1 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 0.4561 & Validation Loss: 0.5055
# Validation loss decreased --- Saving model ...
# 6th Epoch starting.
# Epoch [6] Train Loss: 0.4012 & Validation Loss: 0.4749
# Validation loss decreased --- Saving model ...
# 7th Epoch starting.
# Epoch [7] Train Loss: 0.3548 & Validation Loss: 0.4944
# EarlyStopping counter: 1 out of 20
# 8th Epoch starting.
# Epoch [8] Train Loss: 0.3158 & Validation Loss: 0.4351
# Validation loss decreased --- Saving model ...
# 9th Epoch starting.
# Epoch [9] Train Loss: 0.2939 & Validation Loss: 0.4708
# EarlyStopping counter: 1 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 0.2829 & Validation Loss: 0.4353
# EarlyStopping counter: 2 out of 20
# 11th Epoch starting.
# Epoch [11] Train Loss: 0.2533 & Validation Loss: 0.4135
# Validation loss decreased --- Saving model ...
# 12th Epoch starting.
# Epoch [12] Train Loss: 0.2414 & Validation Loss: 0.4370
# EarlyStopping counter: 1 out of 20
# 13th Epoch starting.
# Epoch [13] Train Loss: 0.2237 & Validation Loss: 0.4119
# Validation loss decreased --- Saving model ...
# 14th Epoch starting.
# Epoch [14] Train Loss: 0.2113 & Validation Loss: 0.4561
# EarlyStopping counter: 1 out of 20
# 15th Epoch starting.
# Epoch [15] Train Loss: 0.1972 & Validation Loss: 0.4248
# EarlyStopping counter: 2 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 0.1825 & Validation Loss: 0.4273
# EarlyStopping counter: 3 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 0.1769 & Validation Loss: 0.4464
# EarlyStopping counter: 4 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 0.1642 & Validation Loss: 0.4492
# EarlyStopping counter: 5 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 0.1598 & Validation Loss: 0.4199
# EarlyStopping counter: 6 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 0.1454 & Validation Loss: 0.4297
# EarlyStopping counter: 7 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 0.1496 & Validation Loss: 0.4955
# EarlyStopping counter: 8 out of 20
# 22th Epoch starting.
# Epoch [22] Train Loss: 0.1329 & Validation Loss: 0.4082
# Validation loss decreased --- Saving model ...
# 23th Epoch starting.
# Epoch [23] Train Loss: 0.1266 & Validation Loss: 0.4495
# EarlyStopping counter: 1 out of 20
# 24th Epoch starting.
# Epoch [24] Train Loss: 0.1238 & Validation Loss: 0.4754
# EarlyStopping counter: 2 out of 20
# 25th Epoch starting.
# Epoch [25] Train Loss: 0.1166 & Validation Loss: 0.4216
# EarlyStopping counter: 3 out of 20
# 26th Epoch starting.
# Epoch [26] Train Loss: 0.1086 & Validation Loss: 0.4643
# EarlyStopping counter: 4 out of 20
# 27th Epoch starting.
# Epoch [27] Train Loss: 0.1082 & Validation Loss: 0.4281
# EarlyStopping counter: 5 out of 20
# 28th Epoch starting.
# Epoch [28] Train Loss: 0.1019 & Validation Loss: 0.4629
# EarlyStopping counter: 6 out of 20
# 29th Epoch starting.
# Epoch [29] Train Loss: 0.0963 & Validation Loss: 0.4559
# EarlyStopping counter: 7 out of 20
# 30th Epoch starting.
# Epoch [30] Train Loss: 0.0975 & Validation Loss: 0.4338
# EarlyStopping counter: 8 out of 20
# 31th Epoch starting.
# Epoch [31] Train Loss: 0.0912 & Validation Loss: 0.4599
# EarlyStopping counter: 9 out of 20
# 32th Epoch starting.
# Epoch [32] Train Loss: 0.0877 & Validation Loss: 0.5114
# EarlyStopping counter: 10 out of 20
# 33th Epoch starting.
# Epoch [33] Train Loss: 0.0847 & Validation Loss: 0.4558
# EarlyStopping counter: 11 out of 20
# 34th Epoch starting.
# Epoch [34] Train Loss: 0.0782 & Validation Loss: 0.5111
# EarlyStopping counter: 12 out of 20
# 35th Epoch starting.
# Epoch [35] Train Loss: 0.0797 & Validation Loss: 0.5351
# EarlyStopping counter: 13 out of 20
# 36th Epoch starting.
# Epoch [36] Train Loss: 0.0721 & Validation Loss: 0.5182
# EarlyStopping counter: 14 out of 20
# 37th Epoch starting.
# Epoch [37] Train Loss: 0.0717 & Validation Loss: 0.5394
# EarlyStopping counter: 15 out of 20
# 38th Epoch starting.
# Epoch [38] Train Loss: 0.0692 & Validation Loss: 0.5155
# EarlyStopping counter: 16 out of 20
# 39th Epoch starting.
# Epoch [39] Train Loss: 0.0710 & Validation Loss: 0.5091
# EarlyStopping counter: 17 out of 20
# 40th Epoch starting.
# Epoch [40] Train Loss: 0.0674 & Validation Loss: 0.5288
# EarlyStopping counter: 18 out of 20
# 41th Epoch starting.
# Epoch [41] Train Loss: 0.0632 & Validation Loss: 0.4831
# EarlyStopping counter: 19 out of 20
# 42th Epoch starting.
# Epoch [42] Train Loss: 0.0596 & Validation Loss: 0.5065
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 3 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 0.6620 & Validation Loss: 0.6223
# Validation loss decreased (inf --> 0.6223).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 0.3328 & Validation Loss: 0.3947
# Validation loss decreased --- Saving model ...
# 3th Epoch starting.
# Epoch [3] Train Loss: 0.2268 & Validation Loss: 0.4001
# EarlyStopping counter: 1 out of 20
# 4th Epoch starting.
# Epoch [4] Train Loss: 0.1880 & Validation Loss: 0.4327
# EarlyStopping counter: 2 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 0.1594 & Validation Loss: 0.3877
# Validation loss decreased --- Saving model ...
# 6th Epoch starting.
# Epoch [6] Train Loss: 0.1449 & Validation Loss: 0.4784
# EarlyStopping counter: 1 out of 20
# 7th Epoch starting.
# Epoch [7] Train Loss: 0.1374 & Validation Loss: 0.4554
# EarlyStopping counter: 2 out of 20
# 8th Epoch starting.
# Epoch [8] Train Loss: 0.1242 & Validation Loss: 0.4471
# EarlyStopping counter: 3 out of 20
# 9th Epoch starting.
# Epoch [9] Train Loss: 0.1230 & Validation Loss: 0.4799
# EarlyStopping counter: 4 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 0.1102 & Validation Loss: 0.4081
# EarlyStopping counter: 5 out of 20
# 11th Epoch starting.
# Epoch [11] Train Loss: 0.1072 & Validation Loss: 0.4368
# EarlyStopping counter: 6 out of 20
# 12th Epoch starting.
# Epoch [12] Train Loss: 0.1001 & Validation Loss: 0.4092
# EarlyStopping counter: 7 out of 20
# 13th Epoch starting.
# Epoch [13] Train Loss: 0.0990 & Validation Loss: 0.4363
# EarlyStopping counter: 8 out of 20
# 14th Epoch starting.
# Epoch [14] Train Loss: 0.0908 & Validation Loss: 0.4687
# EarlyStopping counter: 9 out of 20
# 15th Epoch starting.
# Epoch [15] Train Loss: 0.0852 & Validation Loss: 0.4918
# EarlyStopping counter: 10 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 0.0902 & Validation Loss: 0.4248
# EarlyStopping counter: 11 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 0.0824 & Validation Loss: 0.4366
# EarlyStopping counter: 12 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 0.0760 & Validation Loss: 0.4793
# EarlyStopping counter: 13 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 0.0765 & Validation Loss: 0.4577
# EarlyStopping counter: 14 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 0.0773 & Validation Loss: 0.4888
# EarlyStopping counter: 15 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 0.0663 & Validation Loss: 0.5544
# EarlyStopping counter: 16 out of 20
# 22th Epoch starting.
# Epoch [22] Train Loss: 0.0683 & Validation Loss: 0.4893
# EarlyStopping counter: 17 out of 20
# 23th Epoch starting.
# Epoch [23] Train Loss: 0.0606 & Validation Loss: 0.5425
# EarlyStopping counter: 18 out of 20
# 24th Epoch starting.
# Epoch [24] Train Loss: 0.0669 & Validation Loss: 0.5254
# EarlyStopping counter: 19 out of 20
# 25th Epoch starting.
# Epoch [25] Train Loss: 0.0611 & Validation Loss: 0.4943
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 4 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 0.4087 & Validation Loss: 0.4359
# Validation loss decreased (inf --> 0.4359).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 0.2629 & Validation Loss: 0.4277
# Validation loss decreased --- Saving model ...
# 3th Epoch starting.
# Epoch [3] Train Loss: 0.1935 & Validation Loss: 0.4440
# EarlyStopping counter: 1 out of 20
# 4th Epoch starting.
# Epoch [4] Train Loss: 0.1563 & Validation Loss: 0.3938
# Validation loss decreased --- Saving model ...
# 5th Epoch starting.
# Epoch [5] Train Loss: 0.1513 & Validation Loss: 0.4229
# EarlyStopping counter: 1 out of 20
# 6th Epoch starting.
# Epoch [6] Train Loss: 0.1285 & Validation Loss: 0.4203
# EarlyStopping counter: 2 out of 20
# 7th Epoch starting.
# Epoch [7] Train Loss: 0.1245 & Validation Loss: 0.4000
# EarlyStopping counter: 3 out of 20
# 8th Epoch starting.
# Epoch [8] Train Loss: 0.1108 & Validation Loss: 0.4818
# EarlyStopping counter: 4 out of 20
# 9th Epoch starting.
# Epoch [9] Train Loss: 0.1072 & Validation Loss: 0.4792
# EarlyStopping counter: 5 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 0.1019 & Validation Loss: 0.4507
# EarlyStopping counter: 6 out of 20
# 11th Epoch starting.
# Epoch [11] Train Loss: 0.0943 & Validation Loss: 0.4106
# EarlyStopping counter: 7 out of 20
# 12th Epoch starting.
# Epoch [12] Train Loss: 0.0943 & Validation Loss: 0.4579
# EarlyStopping counter: 8 out of 20
# 13th Epoch starting.
# Epoch [13] Train Loss: 0.0915 & Validation Loss: 0.4593
# EarlyStopping counter: 9 out of 20
# 14th Epoch starting.
# Epoch [14] Train Loss: 0.0830 & Validation Loss: 0.4704
# EarlyStopping counter: 10 out of 20
# 15th Epoch starting.
# Epoch [15] Train Loss: 0.0756 & Validation Loss: 0.4313
# EarlyStopping counter: 11 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 0.0798 & Validation Loss: 0.4935
# EarlyStopping counter: 12 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 0.0706 & Validation Loss: 0.5048
# EarlyStopping counter: 13 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 0.0724 & Validation Loss: 0.4951
# EarlyStopping counter: 14 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 0.0749 & Validation Loss: 0.4755
# EarlyStopping counter: 15 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 0.0655 & Validation Loss: 0.5045
# EarlyStopping counter: 16 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 0.0660 & Validation Loss: 0.5088
# EarlyStopping counter: 17 out of 20
# 22th Epoch starting.
# Epoch [22] Train Loss: 0.0623 & Validation Loss: 0.4521
# EarlyStopping counter: 18 out of 20
# 23th Epoch starting.
# Epoch [23] Train Loss: 0.0575 & Validation Loss: 0.5182
# EarlyStopping counter: 19 out of 20
# 24th Epoch starting.
# Epoch [24] Train Loss: 0.0566 & Validation Loss: 0.5263
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 5 Fold is Training
# 1th Epoch starting.
# Epoch [1] Train Loss: 0.3200 & Validation Loss: 0.4080
# Validation loss decreased (inf --> 0.4080).  Saving model ...
# 2th Epoch starting.
# Epoch [2] Train Loss: 0.2254 & Validation Loss: 0.3878
# Validation loss decreased --- Saving model ...
# 3th Epoch starting.
# Epoch [3] Train Loss: 0.1583 & Validation Loss: 0.3712
# Validation loss decreased --- Saving model ...
# 4th Epoch starting.
# Epoch [4] Train Loss: 0.1390 & Validation Loss: 0.4184
# EarlyStopping counter: 1 out of 20
# 5th Epoch starting.
# Epoch [5] Train Loss: 0.1302 & Validation Loss: 0.4104
# EarlyStopping counter: 2 out of 20
# 6th Epoch starting.
# Epoch [6] Train Loss: 0.1213 & Validation Loss: 0.4264
# EarlyStopping counter: 3 out of 20
# 7th Epoch starting.
# Epoch [7] Train Loss: 0.1088 & Validation Loss: 0.4201
# EarlyStopping counter: 4 out of 20
# 8th Epoch starting.
# Epoch [8] Train Loss: 0.1095 & Validation Loss: 0.4209
# EarlyStopping counter: 5 out of 20
# 9th Epoch starting.
# Epoch [9] Train Loss: 0.0978 & Validation Loss: 0.4241
# EarlyStopping counter: 6 out of 20
# 10th Epoch starting.
# Epoch [10] Train Loss: 0.0925 & Validation Loss: 0.4225
# EarlyStopping counter: 7 out of 20
# 11th Epoch starting.
# Epoch [11] Train Loss: 0.0921 & Validation Loss: 0.4479
# EarlyStopping counter: 8 out of 20
# 12th Epoch starting.
# Epoch [12] Train Loss: 0.0835 & Validation Loss: 0.4551
# EarlyStopping counter: 9 out of 20
# 13th Epoch starting.
# Epoch [13] Train Loss: 0.0791 & Validation Loss: 0.4938
# EarlyStopping counter: 10 out of 20
# 14th Epoch starting.
# Epoch [14] Train Loss: 0.0785 & Validation Loss: 0.4738
# EarlyStopping counter: 11 out of 20
# 15th Epoch starting.
# Epoch [15] Train Loss: 0.0767 & Validation Loss: 0.4589
# EarlyStopping counter: 12 out of 20
# 16th Epoch starting.
# Epoch [16] Train Loss: 0.0719 & Validation Loss: 0.4895
# EarlyStopping counter: 13 out of 20
# 17th Epoch starting.
# Epoch [17] Train Loss: 0.0674 & Validation Loss: 0.4291
# EarlyStopping counter: 14 out of 20
# 18th Epoch starting.
# Epoch [18] Train Loss: 0.0645 & Validation Loss: 0.5104
# EarlyStopping counter: 15 out of 20
# 19th Epoch starting.
# Epoch [19] Train Loss: 0.0652 & Validation Loss: 0.4759
# EarlyStopping counter: 16 out of 20
# 20th Epoch starting.
# Epoch [20] Train Loss: 0.0646 & Validation Loss: 0.4749
# EarlyStopping counter: 17 out of 20
# 21th Epoch starting.
# Epoch [21] Train Loss: 0.0615 & Validation Loss: 0.4942
# EarlyStopping counter: 18 out of 20
# 22th Epoch starting.
# Epoch [22] Train Loss: 0.0603 & Validation Loss: 0.4891
# EarlyStopping counter: 19 out of 20
# 23th Epoch starting.
# Epoch [23] Train Loss: 0.0549 & Validation Loss: 0.5194
# EarlyStopping counter: 20 out of 20
# Early Stopping!!
# 6241.249737977982

# %%
test_model(model)
# Out:
# [Test set] Average loss: 0.0030, Accuracy: 8894/10000 (88.94%)
